# %%
import numpy as np
import pandas as pd

# %%
pip install --upgrade pynytimes
# Out:
# Requirement already satisfied: pynytimes in c:\users\admin\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: urllib3 in c:\users\admin\anaconda3\lib\site-packages (from pynytimes) (1.26.7)
# Requirement already satisfied: requests<3.0.0,>=2.10.0 in c:\users\admin\anaconda3\lib\site-packages (from pynytimes) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.10.0->pynytimes) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.10.0->pynytimes) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0,>=2.10.0->pynytimes) (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import time
import requests
import datetime
import dateutil
import pandas as pd
from dateutil.relativedelta import relativedelta

# %%
# функция, проверяющая наличие нужных слов для фильтрации статей
def is_rus(s):
    d = ['Russia', 'Putin', 'Kremlin', 'Vladimir', 'Kremlin', 'Yeltsyn', 'Medvedev']
    flag = False
    for el in d:
        if el in s:
            flag = True
            break
    return flag

# %%
# функция, отправляющая запрос архиву за определенную дату
def send_request(date):
    base_url = 'https://api.nytimes.com/svc/archive/v1/'
    url = base_url + '/' + date[0] + '/' + date[1] + '.json?api-key=' + 'B9KoXybdjViG9meU21nn9QAvrDbJdx26'
    response = requests.get(url).json()
    time.sleep(6)
    return response

# функция, проверяющая наличие заголовка и наличие необходимых слов в заголовке или абстракте
def is_valid(article, date):
    has_headline = type(article['headline']) == dict and 'main' in article['headline'].keys()
    return has_headline and (is_rus(article['headline']) or is_rus(article['abstract']))


# функция, осуществляющая парсинг данных и создание датафрейма
def parse_response(response):
    data = {'headline': [],  
        'date': [], 
        'doc_type': [],
        'material_type': [],
        'section': [],
        'keywords': [],
        'abstract': [],
        'lead': [],
        'word_count': []}
    
    articles = response['response']['docs'] 
    for article in articles: # For each article, make sure it falls within our date range
        date = dateutil.parser.parse(article['pub_date']).date()
        if is_valid(article, date):
            data['date'].append(date)
            data['headline'].append(article['headline']['main']) 
            if 'section' in article:
                data['section'].append(article['section_name'])
            else:
                data['section'].append(None)
            data['doc_type'].append(article['document_type'])
            if 'type_of_material' in article: 
                data['material_type'].append(article['type_of_material'])
            else:
                data['material_type'].append(None)
            keywords = [keyword['value'] for keyword in article['keywords'] if keyword['name'] == 'subject']
            data['keywords'].append(keywords)
            data['abstract'].append(article['abstract'])
            data['lead'].append(article['lead_paragraph'])
            if 'word_count' in article:
                data['word_count'].append(article['word_count'])
    return pd.DataFrame(data) 

# отправление и парсинг запроса
def get_data(dates):
    total = 0
    print('Date range: ' + str(dates[0]) + ' to ' + str(dates[-1]))
    if not os.path.exists('headlines'):
        os.mkdir('headlines')
    for date in dates:
        response = send_request(date)
        df = parse_response(response)
        total += len(df)
        df.to_csv('headlines/' + date[0] + '-' + date[1] + '.csv', index=False)
        print('Saving headlines/' + date[0] + '-' + date[1] + '.csv...')
    print('Number of articles collected: ' + str(total))

# %%
date_range = []
for i in range(1991, 2023):
    date_range.append([str(i), str(1)])
    date_range.append([str(i), str(6)])
    date_range.append([str(i), str(12)])

# %%
get_data(date_range)
# Out:
# Date range: ['1991', '1'] to ['2022', '12']
# Saving headlines/1991-1.csv...
# Saving headlines/1991-6.csv...
# Saving headlines/1991-12.csv...
# Saving headlines/1992-1.csv...
# Saving headlines/1992-6.csv...
# Saving headlines/1992-12.csv...
# Saving headlines/1993-1.csv...
# Saving headlines/1993-6.csv...
# Saving headlines/1993-12.csv...
# Saving headlines/1994-1.csv...
# Saving headlines/1994-6.csv...
# Saving headlines/1994-12.csv...
# Saving headlines/1995-1.csv...
# Saving headlines/1995-6.csv...
# Saving headlines/1995-12.csv...
# Saving headlines/1996-1.csv...
# Saving headlines/1996-6.csv...
# Saving headlines/1996-12.csv...
# Saving headlines/1997-1.csv...
# Saving headlines/1997-6.csv...
# Saving headlines/1997-12.csv...
# Saving headlines/1998-1.csv...
# Saving headlines/1998-6.csv...
# Saving headlines/1998-12.csv...
# Saving headlines/1999-1.csv...
# Saving headlines/1999-6.csv...
# Saving headlines/1999-12.csv...
# Saving headlines/2000-1.csv...
# Saving headlines/2000-6.csv...
# Saving headlines/2000-12.csv...
# Saving headlines/2001-1.csv...
# Saving headlines/2001-6.csv...
# Saving headlines/2001-12.csv...
# Saving headlines/2002-1.csv...
# Saving headlines/2002-6.csv...
# Saving headlines/2002-12.csv...
# Saving headlines/2003-1.csv...
# Saving headlines/2003-6.csv...
# Saving headlines/2003-12.csv...
# Saving headlines/2004-1.csv...
# Saving headlines/2004-6.csv...
# Saving headlines/2004-12.csv...
# Saving headlines/2005-1.csv...
# Saving headlines/2005-6.csv...
# Saving headlines/2005-12.csv...
# Saving headlines/2006-1.csv...
# Saving headlines/2006-6.csv...
# Saving headlines/2006-12.csv...
# Saving headlines/2007-1.csv...
# Saving headlines/2007-6.csv...
# Saving headlines/2007-12.csv...
# Saving headlines/2008-1.csv...
# Saving headlines/2008-6.csv...
# Saving headlines/2008-12.csv...
# Saving headlines/2009-1.csv...
# Saving headlines/2009-6.csv...
# Saving headlines/2009-12.csv...
# Saving headlines/2010-1.csv...
# Saving headlines/2010-6.csv...
# Saving headlines/2010-12.csv...
# Saving headlines/2011-1.csv...
# Saving headlines/2011-6.csv...
# Saving headlines/2011-12.csv...
# Saving headlines/2012-1.csv...
# Saving headlines/2012-6.csv...
# Saving headlines/2012-12.csv...
# Saving headlines/2013-1.csv...
# Saving headlines/2013-6.csv...
# Saving headlines/2013-12.csv...
# Saving headlines/2014-1.csv...
# Saving headlines/2014-6.csv...
# Saving headlines/2014-12.csv...
# Saving headlines/2015-1.csv...
# Saving headlines/2015-6.csv...
# Saving headlines/2015-12.csv...
# Saving headlines/2016-1.csv...
# Saving headlines/2016-6.csv...
# Saving headlines/2016-12.csv...
# Saving headlines/2017-1.csv...
# Saving headlines/2017-6.csv...
# Saving headlines/2017-12.csv...
# Saving headlines/2018-1.csv...
# Saving headlines/2018-6.csv...
# Saving headlines/2018-12.csv...
# Saving headlines/2019-1.csv...
# Saving headlines/2019-6.csv...
# Saving headlines/2019-12.csv...
# Saving headlines/2020-1.csv...
# Saving headlines/2020-6.csv...
# Saving headlines/2020-12.csv...
# Saving headlines/2021-1.csv...
# Saving headlines/2021-6.csv...
# Saving headlines/2021-12.csv...
# Saving headlines/2022-1.csv...
# Saving headlines/2022-6.csv...
# Saving headlines/2022-12.csv...
# Number of articles collected: 8930

# %%
df = pd.read_csv('headlines/1991-1.csv')
for i in range(1991, 2023):
    for el in [1, 6, 12]:
        if el != 1 and i != 1991:
            df1 = pd.read_csv(f'headlines/{i}-{el}.csv')
            df = pd.concat([df, df1], ignore_index=True)
df
# Out:
#                                                headline        date doc_type  \
# 0                                          NEWS SUMMARY  1991-01-01  article
# 1     Review/Television; A Maestro in Exile Is Welco...  1991-01-02  article
# 2         Restive Soviet Republic Yields to the Kremlin  1991-01-02  article
# 3                                          NEWS SUMMARY  1991-01-02  article
# 4                      Detailing the Bolshevik Enormity  1991-01-03  article
# ...                                                 ...         ...      ...
# 6066  Xi and Putin Meet Again, Two Strongmen in a We...  2022-12-30  article
# 6067             One Man Flees Putin’s Draft: An Update  2022-12-30  article
# 6068  ‘The Daily’ checks in with a Russian man who f...  2022-12-30  article
# 6069  Putin and Zelensky will give dueling addresses...  2022-12-31  article
# 6070  Clergymen or Spies? Churches Become Tools of W...  2022-12-31  article
#
#      material_type  section  \
# 0          Summary      NaN
# 1           Review      NaN
# 2             News      NaN
# 3          Summary      NaN
# 4           Review      NaN
# ...            ...      ...
# 6066          News      NaN
# 6067          News      NaN
# 6068          News      NaN
# 6069          News      NaN
# 6070          News      NaN
#
#                                                keywords  \
# 0                                    ['NO INDEX TERMS']
# 1     ['Music', 'Reviews', 'Television', 'Documentar...
# 2     ['Language and Languages', 'MINORITIES (ETHNIC...
# 3                                    ['NO INDEX TERMS']
# 4                                      ['BOOK REVIEWS']
# ...                                                 ...
# 6066  ['International Relations', 'Russian Invasion ...
# 6067               ['Draft and Recruitment (Military)']
# 6068                                                 []
# 6069             ['Russian Invasion of Ukraine (2022)']
# 6070  ['Russian Invasion of Ukraine (2022)', 'Russia...
#
#                                                abstract  \
# 0       INTERNATIONAL 2-7    Iraq would launch missi...
# 1       "Soldiers of Music: Rostropovich Returns to ...
# 2       Acting to defuse one of the Soviet Union's m...
# 3       International A2-10    U.S. military and pol...
# 4       The Russian Revolution By Richard Pipes 944 ...
# ...                                                 ...
# 6066  Russia is isolated by its invasion of Ukraine ...
# 6067  Kirill, a 24-year-old from the Moscow region, ...
# 6068  Kirill, 24, worked at a nonprofit for homeless...
# 6069  Volodymyr Zelensky of Ukraine and Vladimir V. ...
# 6070  Ukrainian officials are cracking down on a bra...
#
#                                                    lead  word_count
# 0                                     INTERNATIONAL 2-7        1042
# 1     "Soldiers of Music: Rostropovich Returns to Ru...         708
# 2     Acting to defuse one of the Soviet Union's mos...         382
# 3                                   International A2-10        1088
# 4     The Russian Revolution By Richard Pipes 944 pa...        1075
# ...                                                 ...         ...
# 6066  When China’s top leader, Xi Jinping, and Presi...        1562
# 6067  This week, The Daily is revisiting some of our...         420
# 6068  Kirill, 24, worked at a nonprofit for homeless...          99
# 6069  With their troops locked in a bloody stalemate...         426
# 6070  KYIV, Ukraine — Andriy Pavlenko, an Orthodox c...        1197
#
# [6071 rows x 9 columns]

# %%
df.to_csv('nyt.csv')
